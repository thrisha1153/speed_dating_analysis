# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\thris\\Desktop\\speed_data_data.csv")
df.head()
# Out:
#    gender   age   income  goal  career  dec  attr  sinc  intel  fun  amb
# 0       0  21.0  69487.0   2.0  lawyer    1   6.0   9.0    7.0  7.0  6.0  \
# 1       0  21.0  69487.0   2.0  lawyer    1   7.0   8.0    7.0  8.0  5.0
# 2       0  21.0  69487.0   2.0  lawyer    1   5.0   8.0    9.0  8.0  5.0
# 3       0  21.0  69487.0   2.0  lawyer    1   7.0   6.0    8.0  7.0  6.0
# 4       0  21.0  69487.0   2.0  lawyer    1   5.0   6.0    7.0  7.0  6.0
#
#    shar  like  prob  met
# 0   5.0   7.0   6.0  2.0
# 1   6.0   7.0   5.0  1.0
# 2   7.0   7.0   NaN  1.0
# 3   8.0   7.0   6.0  2.0
# 4   6.0   6.0   6.0  2.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   gender  8378 non-null   int64
#  1   age     8283 non-null   float64
#  2   income  4279 non-null   float64
#  3   goal    8299 non-null   float64
#  4   career  8289 non-null   object
#  5   dec     8378 non-null   int64
#  6   attr    8176 non-null   float64
#  7   sinc    8101 non-null   float64
#  8   intel   8082 non-null   float64
#  9   fun     8028 non-null   float64
#  10  amb     7666 non-null   float64
#  11  shar    7311 non-null   float64
#  12  like    8138 non-null   float64
#  13  prob    8069 non-null   float64
#  14  met     8003 non-null   float64
# dtypes: float64(12), int64(2), object(1)
# memory usage: 981.9+ KB

# %%
df.describe()
# Out:
#             gender          age         income         goal          dec
# count  8378.000000  8283.000000    4279.000000  8299.000000  8378.000000  \
# mean      0.500597    26.358928   44887.606450     2.122063     0.419909
# std       0.500029     3.566763   17206.920962     1.407181     0.493573
# min       0.000000    18.000000    8607.000000     1.000000     0.000000
# 25%       0.000000    24.000000   31516.000000     1.000000     0.000000
# 50%       1.000000    26.000000   43185.000000     2.000000     0.000000
# 75%       1.000000    28.000000   54303.000000     2.000000     1.000000
# max       1.000000    55.000000  109031.000000     6.000000     1.000000
#
#               attr         sinc        intel          fun          amb
# count  8176.000000  8101.000000  8082.000000  8028.000000  7666.000000  \
# mean      6.189995     7.175164     7.368597     6.400598     6.777524
# std       1.950169     1.740315     1.550453     1.953702     1.794055
# ...

# %%
df.isna().sum()
# Out:
# gender       0
# age         95
# income    4099
# goal        79
# career      89
# dec          0
# attr       202
# sinc       277
# intel      296
# fun        350
# amb        712
# shar      1067
# like       240
# prob       309
# met        375
# dtype: int64

# %%
df.shape
# Out:
# (8378, 15)

# %% [markdown]
# UNIVARIATE

# %%
plt.figure(figsize=(8, 6))
dec_counts = df['gender'].value_counts()
dec_counts.plot(kind='bar', color=['blue', 'orange'])

# Add counts on top of each bar
for i, count in enumerate(dec_counts):
    plt.text(i, count + 0.1, str(count), ha='center')

# Add labels and title
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Count of Gender')

# Add legend
plt.legend(['Female', 'Male'])

# Show the plot
plt.show()

# %% [markdown]
# AGE

# %%
sns.histplot(x="age",data=df,kde=True)
plt.title("Distribution of Age with missing values of 95")
# Out:
# Text(0.5, 1.0, 'Distribution of Age with missing values of 95')

# %% [markdown]
# Most people lies in the range between age of 23 to 28 with the max age of 27.

# %% [markdown]
# Which one to choose, mean or median, depends on the distribution of the data and whether it is affected by outliers:
#
# If the distribution is approximately symmetric and not affected by outliers, mean is a good choice.
# If the distribution is skewed or contains outliers, median is often preferred as it is more robust to extreme values.

# %%
# Calculate the median of the 'age' column
median_age = df['age'].median()

# Fill missing values in the 'age' column with the median
df['age'].fillna(median_age, inplace=True)

# %%
sns.histplot(x="age",data=df,kde=True)
plt.title("Distribution of Age without missing values")
# Out:
# Text(0.5, 1.0, 'Distribution of Age without missing values')

# %% [markdown]
# INCOME

# %%
sns.histplot(x="income",data=df,kde=True)
# Out:
# <Axes: xlabel='income', ylabel='Count'>

# %%
# Calculate the median of the 'age' column
median_income = df['income'].median()

# Fill missing values in the 'age' column with the median
df['income'].fillna(median_income, inplace=True)

# %%
sns.histplot(x="income", data=df, bins=20)
# Out:
# <Axes: xlabel='income', ylabel='Count'>

# %% [markdown]
# Most of the people fall under the $40,000 income.

# %% [markdown]
# Goal -- The meaning of the column is unknowm

# %%
sns.histplot(x="goal",data=df)
# Out:
# <Axes: xlabel='goal', ylabel='Count'>

# %%
sns.boxplot(x="goal",data=df)
# Out:
# <Axes: xlabel='goal'>

# %%
med_goal=df["goal"].median()
df["goal"].fillna(med_goal,inplace=True)

# %%
sns.histplot(x="goal",data=df)
# Out:
# <Axes: xlabel='goal', ylabel='Count'>

# %% [markdown]
# CARRER

# %%
new=df["career"].value_counts().head(10)

# %%
plt.barh(new.index,new.values,color="purple")
plt.title("Top 10 carrers")
plt.xlabel("count of people")
plt.ylabel("carrer")
# Out:
# Text(0, 0.5, 'carrer')

# %%
df['career'].fillna('Unknown', inplace=True)  # Fill missing values with 'Unknown'

# %%
a=df["career"].value_counts()

df1=pd.DataFrame(a)
df1.head()
# Out:
#             count
# career
# Finance       202
# professor     199
# Lawyer        154
# Professor     148
# Consulting    147

# %% [markdown]
# dec -- raters decision on whether this individual was a match

# %%
plt.figure(figsize=(8, 6))
dec_counts = df['dec'].value_counts()
dec_counts.plot(kind='bar', color=['blue', 'orange'])

# Add counts on top of each bar
for i, count in enumerate(dec_counts):
    plt.text(i, count + 0.1, str(count), ha='center')

# Add labels and title
plt.xlabel('Decision (dec)')
plt.ylabel('Count')
plt.title('Count of Decision (dec)')
plt.legend(['Yes', 'No'])

# Show the plot
plt.show()

# %% [markdown]
# The decision "yes" meaning they like the date is more when compaered to rejecting the date

# %% [markdown]
# BOXPLOTS OF MULTIPLE COLUMNS

# %%
plt.figure(figsize=(10, 6))
df.boxplot(column=["attr","sinc","intel","fun","amb","shar","like","prob","met"])

plt.xlabel('Columns')
plt.ylabel('Values')
plt.title("With missing values")

# Show the plot
plt.show()

# %%
print(df["met"].value_counts())
sns.histplot(x="met",data=df)
# Out:
# met
# 0.0    4047
# 2.0    3597
# 1.0     351
# 7.0       3
# 5.0       2
# 3.0       1
# 8.0       1
# 6.0       1
# Name: count, dtype: int64
# <Axes: xlabel='met', ylabel='Count'>

# %%
columns_to_fill = ['attr', 'sinc', 'intel', 'fun', 'amb', 'shar', 'like', 'prob', 'met']

# Fill missing values in the specified columns with median
for column in columns_to_fill:
    median_value = df[column].median()  # Calculate the median for each column
    df[column].fillna(median_value, inplace=True)

# %%
plt.figure(figsize=(10, 6))
df.boxplot(column=["attr","sinc","intel","fun","amb","shar","like","prob","met"])

plt.xlabel('Columns')
plt.ylabel('Values')
plt.title("Without missing values")
# Show the plot
plt.show()

# %% [markdown]
# BIVARIATE and MULTIVARIATE

# %%
df.columns
# Out:
# Index(['gender', 'age', 'income', 'goal', 'career', 'dec', 'attr', 'sinc',
#        'intel', 'fun', 'amb', 'shar', 'like', 'prob', 'met'],
#       dtype='object')

# %%
sns.scatterplot(x="income",y="age",data=df)
plt.title("Age vs Income")
plt.ylabel("Age")
plt.xlabel("Income")
# Out:
# Text(0.5, 0, 'Income')

# %%
sns.scatterplot(x="income",y="age",data=df,hue="gender")
plt.title("Age vs Income")
plt.ylabel("Age")
plt.xlabel("Income")
# Out:
# Text(0.5, 0, 'Income')

# %%
sns.scatterplot(x="age",y="attr",data=df,hue="gender")
plt.title("Age vs Attractiveness")
plt.xlabel("Age")
plt.ylabel("Attractiveness")
# Out:
# Text(0, 0.5, 'Attractiveness')

# %% [markdown]
# Female of age 55 also has more attractiveness ratings. Age 20 to 37 are also more attarctive. MAle has been found more attractive rather than female.

# %%
sns.scatterplot(x="shar",y="like",data=df,hue="gender")
# Out:
# <Axes: xlabel='shar', ylabel='like'>

# %%
sns.pairplot(df)

# %%
df=df.drop("career",axis=1)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f")

# Add title
plt.title('Correlation Heatmap')

# Show plot
plt.show()

# %%
x=df[["gender","attr","sinc","intel","fun","amb","shar","like","prob"]]
y=df["dec"]

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8,random_state=42)

# %% [markdown]
# DECISION TREE

# %%
dc=DecisionTreeClassifier()
dc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
yp=dc.predict(x_test)

# %%
classification_report(y_test,yp)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.74      0.75      0.74      3884\n           1       0.65      0.64      0.64      2819\n\n    accuracy                           0.70      6703\n   macro avg       0.69      0.69      0.69      6703\nweighted avg       0.70      0.70      0.70      6703\n'

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,yp)
# Out:
# 0.7020736983440251

# %% [markdown]
# RANDOM FOREST CLASSIFIER

# %%
from sklearn.ensemble import RandomForestClassifier
rc=RandomForestClassifier()

# %%
rc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
ypp=rc.predict(x_test)

# %%
metrics.accuracy_score(y_test,ypp)
# Out:
# 0.7593614799343578

# %% [markdown]
# XGBOOST

# %%
# !pip install xgboost
import xgboost as xgb
# Out:
# ...
#                                               0.0/99.8 MB ? eta -:--:--
#                                               0.3/99.8 MB 8.3 MB/s eta 0:00:12
#                                               0.4/99.8 MB 4.6 MB/s eta 0:00:22
#                                               0.5/99.8 MB 3.9 MB/s eta 0:00:26
#                                               0.5/99.8 MB 3.7 MB/s eta 0:00:27
#                                               0.5/99.8 MB 3.7 MB/s eta 0:00:27
#                                               0.8/99.8 MB 3.2 MB/s eta 0:00:32
#                                               0.9/99.8 MB 2.7 MB/s eta 0:00:38
#                                               1.0/99.8 MB 2.6 MB/s eta 0:00:38
#                                               1.2/99.8 MB 2.7 MB/s eta 0:00:37
#                                               1.3/99.8 MB 2.7 MB/s eta 0:00:37
#                                               1.4/99.8 MB 2.8 MB/s eta 0:00:36
# ...

# %%
xgb_clf = xgb.XGBClassifier()
xgb_clf.fit(x_train, y_train)

# Predict on the test set
y_pred = xgb_clf.predict(x_test)

# %%
accuracy = metrics.accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.756526928241086

# %% [markdown]
# GRADIENT BOOSTING ALGO

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbm_clf = GradientBoostingClassifier()
gbm_clf.fit(x_train, y_train)

# Predict on the test set
y_pre = gbm_clf.predict(x_test)

# Evaluate the model
accuracy = metrics.accuracy_score(y_test, y_pre)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7641354617335522

# %% [markdown]
# SUPPORT VECTOR MACHINE

# %%
from sklearn.svm import SVC

svm_clf = SVC()
svm_clf.fit(x_train, y_train)

# Predict on the test set
y_pr = svm_clf.predict(x_test)

# Evaluate the model
accuracy = metrics.accuracy_score(y_test, y_pr)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7687602566015217

# %% [markdown]
# KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier()
knn.fit(x_train, y_train)

# Predict on the test set
y_p = svm_clf.predict(x_test)

# Evaluate the model
accuracy = metrics.accuracy_score(y_test, y_p)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.7687602566015217
